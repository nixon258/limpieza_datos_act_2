# %%
from mis_scripts import funciones as ld
import importlib
importlib.reload(ld)
# Out:
# <module 'mis_scripts.funciones' from 'C:\\Users\\juanb\\PycharmProjects\\limpieza_datos_act_2\\mis_scripts\\funciones.py'>

# %%
url ="data/online_retail_dirty_maestria.csv"

# %%
df = ld.importar_datos(url)

# %%
duplicados = ld.obtener_duplicados(df)
df = ld.eliminar_duplicados(df)

# %%
df = ld.eliminar_columna(df, 'CustomerID')

# %%
df = ld.limpiar_simbolo_moneda(df)
df = ld.convertir_a_numerico(df, 'UnitPrice')

# %%
ceros = ld.obtener_valores_cero(df, 'UnitPrice')
df = ld.filtrar_mayores_a_cero(df, 'UnitPrice')

# %%
nulos_q = ld.obtener_nulos(df, 'Quantity')
negativos_q = ld.obtener_negativos(df, 'Quantity')

# %%
df = ld.convertir_a_absoluto(df, 'Quantity')
df = ld.eliminar_nulos(df, 'Quantity')

# %%
df = ld.convertir_a_fecha(df, 'InvoiceDate')

# %%
valores = ld.obtener_valores_unicos(df, 'Country')
df = ld.reemplazar_valores(df, 'Country',
                          ['United  Kingdom', 'U.K.', 'UK', 'united kingdom'],
                          'United Kingdom')

# %%
df_map = ld.agrupar_por_pais(df)
fig = ld.crear_mapa(df_map)
ld.mostrar_mapa(fig)
